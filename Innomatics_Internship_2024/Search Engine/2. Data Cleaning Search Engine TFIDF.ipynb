# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/data_frame_searchengine.csv')

# %%
df.shape
# Out:
# (24749, 4)

# %%
df.columns
# Out:
# Index(['num', 'name', 'content', 'file_content'], dtype='object')

# %%
df_new = df[['num', 'name', 'file_content']]

# %%
df_new
# Out:
#            num                                               name  \
# 0      9504163       mis.juhtus.andres.lapeteusega.(1966).eng.1cd
# 1      9442913                             michael.(2023).eng.1cd
# 2      9391327  king.of.the.hill.s12.e02.bobby.rae.(2007).eng.1cd
# 3      9247893  doc.martin.s01.e02.gentlemen.prefer.(2004).eng...
# 4      9418015           class.s01.e06.episode.1.6.(2023).eng.1cd
# ...        ...                                                ...
# 24744  9466890  csi.miami.s06.e20.down.to.the.wire.(2008).eng.1cd
# 24745  9268430      nova.s46.e18.look.whos.driving.(2019).eng.1cd
# 24746  9323572        entourage.s05.e06.redomption.(2008).eng.1cd
# 24747  9267122                kaidan.semushi.otoko.(1965).eng.1cd
# 24748  9204642       the.deuce.s01.e04.i.see.money.(2017).eng.1cd
#
#                                             file_content
# 0      ï»¿1\r\n00:00:42,908 --> 00:00:48,933\r\nWHAT ...
# 1      1\r\n00:00:06,000 --> 00:00:12,074\r\napi.Open...
# 2      ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nSuppo...
# 3      1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4      ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\napi.O...
# ...                                                  ...
# 24744  ï»¿1\r\n00:00:04,071 --> 00:00:10,242\r\n(phon...
# 24745  ï»¿1\r\n00:00:01,835 --> 00:00:03,531\r\nA let...
# 24746  ï»¿1\r\n00:00:07,441 --> 00:00:09,474\r\n<i>(t...
# 24747  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 24748  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nSuppo...
#
# [24749 rows x 3 columns]

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(raw_text):
    # Remove HTML tags
    text = BeautifulSoup(raw_text, 'html.parser').get_text()
    
    # Removing special characters and digits
    special_char = re.sub("[^a-zA-Z]", " ", text)
    
    # change sentence to lower case
    lowered = special_char.lower()
    
    
    sentence = re.sub('\s+', ' ', lowered)

    tokens = sentence.split()
    
    # Lemmatization
    clean_tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    return pd.Series([" ".join(clean_tokens), len(clean_tokens)])

# %%
from tqdm import tqdm, tqdm_notebook
import re
from bs4 import BeautifulSoup

# %%
# Register `pandas.progress_apply` and `pandas.Series.map_apply` with `tqdm`

tqdm.pandas()

# %%
# Now you can use `progress_apply` instead of `apply`
# and `progress_map` instead of `map`

temp_df = df_new['file_content'].progress_apply(lambda x: preprocess(x))

temp_df.head()
# Out:
#  85%|████████████████████████████████████████████████████████████████▌           | 21038/24749 [11:58<01:45, 35.26it/s]C:\Users\hp\AppData\Local\Temp\ipykernel_12648\2355623552.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(raw_text, 'html.parser').get_text()
# 100%|████████████████████████████████████████████████████████████████████████████| 24749/24749 [14:03<00:00, 29.34it/s]
#                                                    0     1
# 0  what happened to andres lapeteus andres lapete...  7420
# 1  api opensubtitles org is deprecated please imp...  8124
# 2  support u and become vip member to remove all ...  2791
# 3  watch any video online with open subtitle free...  4726
# 4  api opensubtitles org is deprecated please imp...  3947

# %%
temp_df.columns = ['clean_text_lemma', 'text_length_lemma']

temp_df.head()
# Out:
#                                     clean_text_lemma  text_length_lemma
# 0  what happened to andres lapeteus andres lapete...               7420
# 1  api opensubtitles org is deprecated please imp...               8124
# 2  support u and become vip member to remove all ...               2791
# 3  watch any video online with open subtitle free...               4726
# 4  api opensubtitles org is deprecated please imp...               3947

# %%
df_new = pd.concat([df_new, temp_df], axis=1)
df_new.head()
# Out:
#        num                                               name  \
# 0  9504163       mis.juhtus.andres.lapeteusega.(1966).eng.1cd
# 1  9442913                             michael.(2023).eng.1cd
# 2  9391327  king.of.the.hill.s12.e02.bobby.rae.(2007).eng.1cd
# 3  9247893  doc.martin.s01.e02.gentlemen.prefer.(2004).eng...
# 4  9418015           class.s01.e06.episode.1.6.(2023).eng.1cd
#
#                                         file_content  \
# 0  ï»¿1\r\n00:00:42,908 --> 00:00:48,933\r\nWHAT ...
# 1  1\r\n00:00:06,000 --> 00:00:12,074\r\napi.Open...
# 2  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nSuppo...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\napi.O...
#
#                                     clean_text_lemma  text_length_lemma
# 0  what happened to andres lapeteus andres lapete...               7420
# 1  api opensubtitles org is deprecated please imp...               8124
# 2  support u and become vip member to remove all ...               2791
# 3  watch any video online with open subtitle free...               4726
# 4  api opensubtitles org is deprecated please imp...               3947

# %%
df_10 = df_new.sample(frac=0.1)

# %%
df_10
# Out:
#            num                                               name  \
# 17759  9293242  military.prosecutor.do.bae.man.s01.e09.the.lea...
# 16487  9500947  alfred.hitchcock.presents.s01.e20.and.so.died....
# 18634  9452413  big.time.rush.s02.e16.big.time.girl.group.(201...
# 17531  9406362                      quest.for.love.(2022).eng.1cd
# 2708   9515069  ultra.city.smiths.s01.e03.hot.clues.(2021).eng...
# ...        ...                                                ...
# 16046  9225836  the.croods.family.tree.s04.e02.ballincup.(2022...
# 13812  9202357                           thank.you.(2022).eng.1cd
# 19133  9250167  desperate.housewives.s02.e13.theres.something....
# 20320  9509822        hometown.s01.e11.jo.junghyun.(2021).eng.1cd
# 9933   9265573               castle.s04.e06.demons.(2011).eng.1cd
#
#                                             file_content  \
# 17759  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 16487  ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 18634  ï»¿1\r\n00:00:11,500 --> 00:00:13,375\r\n- Gre...
# 17531  1\r\n00:00:00,760 --> 00:00:04,093\r\n(soft or...
# 2708   ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# ...                                                  ...
# 16046  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\napi.O...
# 13812  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\napi.O...
# 19133  ï»¿1\r\n00:00:01,335 --> 00:00:02,934\r\n<i>Pr...
# 20320  ï»¿1\n00:00:13,998 --> 00:00:15,360\n(The char...
# 9933   ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nUse t...
#
#                                         clean_text_lemma  text_length_lemma
# 17759  advertise your product or brand here contact w...               6809
# 16487  script info title default file scripttype v wr...               8256
# 18634  great news boy the news is never great when he...               2816
# 17531  soft orchestral music advertise your product o...              11234
# 2708   script info title default file scripttype v wr...               5428
# ...                                                  ...                ...
# 16046  api opensubtitles org is deprecated please imp...               3254
# 13812  api opensubtitles org is deprecated please imp...               9525
# 19133  previously on desperate housewife if you come ...               5249
# 20320  the character place institution case and organ...               4233
# 9933   use the free code joinnow at www playships eu ...               7336
#
# [2475 rows x 5 columns]

# %%
# df_10.to_csv('data/search_eng_data_21.csv', index=False, escapechar="\\")

# %%
df_10.sample(50)
# Out:
#            num                                               name  \
# 16568  9386361  trigun.stampede.s01.e01.nomans.land.(2023).eng...
# 17274  9446672                  quarantine.for.two.(2021).eng.1cd
# 21694  9395434                        fast.furious.(2009).eng.1cd
# 9570   9400870               buck.and.the.preacher.(1972).eng.1cd
# 3075   9512307  love.is.blind.s04.e07.second.times.the.charm.(...
# 18162  9509838  dimension.20.s12.e06.a.starstruck.odyssey.on.t...
# 11318  9366192     the.following.s01.e07.let.me.go.(2013).eng.1cd
# 21580  9425675  final.moments.s01.e08.the.streets.are.talking....
# 21493  9272092                   the.addams.family.(1991).eng.1cd
# 21434  9417455  downtown.precinct.s02.e05.episode.2.5.(2014).e...
# 16444  9218278     veep.s05.e07.congressional.ball.(2016).eng.1cd
# 236    9341450  earths.tropical.islands.s01.e01.madagascar.(20...
# 13941  9297926            and.the.baton.was.passed.(2021).eng.1cd
# 12890  9495118  transatlantic.s01.e03.the.wilderness.(2023).en...
# 20518  9476233  the.voice.s23.e05.the.blind.auditions.part.5.(...
# 18361  9509935   devil.in.law.s01.e13.episode.1.13.(2023).eng.1cd
# 6019   9316510  the.voice.s22.e12.the.battles.part.5.(2022).en...
# 19337  9499848  guardian.the.lonely.and.great.god.s01.e05.i.ha...
# 10165  9333670                              bleach.(2018).eng.1cd
# 20152  9383902  king.of.the.hill.s08.e19.stressed.for.success....
# 14313  9500054  perry.mason.s02.e06.chapter.fourteen.(2023).en...
# 15872  9416296                         love.island.(2015).eng.1cd
# 24414  9418783   family.guy.s12.e18.baby.got.black.(2014).eng.1cd
# 1087   9388473  the.king.of.queens.s02.e17.meet.byproduct.(200...
# 8547   9371676                           ironheart.(1992).eng.1cd
# 20578  9353232                         camp.murder.(2022).eng.1cd
# 1457   9391946  unlock.my.boss.s01.e08.episode.1.8.(2022).eng.1cd
# 19904  9259536  two.and.a.half.men.s07.e16.tinkle.like.a.princ...
# 13857  9368240  kaun.banegi.shikharwati.earth.wind.and.fire.()...
# 23633  9305249       nature.s23.e02.shark.mountain.(2004).eng.1cd
# 4084   9304448  the.crown.s05.e01.queen.victoria.syndrome.(202...
# 18151  9351873   american.horror.story.s07.e04.119.(2017).eng.1cd
# 9591   9383331                fenris.s01.e04.modre.(2022).eng.1cd
# 14515  9215423                  the.tarix.jabrix.3.(2011).eng.1cd
# 3388   9440294      the.xfiles.s10.e01.my.struggle.(2015).eng.1cd
# 12330  9468287             csi.miami.s03.e05.legal.(2004).eng.1cd
# 14457  9407206    mamas.angel.s01.e10.episode.1.10.(2016).eng.1cd
# 10765  9509030  prisoner.zero.s01.e05.changes.part.two.(2016)....
# 16933  9205287  its.always.sunny.in.philadelphia.s03.e01.the.g...
# 8829   9477048                halo.s01.e01.contact.(2022).eng.1cd
# 5440   9463830  the.simpsons.s34.e16.hostile.kirk.place.(2023)...
# 20605  9418089                               paris.(1998).eng.1cd
# 19127  9346390                         local.color.(1977).eng.1cd
# 16971  9304145  star.trek.the.next.generation.s05.e26.times.ar...
# 14621  9201940           roswell.s01.e09.heat.wave.(1999).eng.1cd
# 160    9344529               love.island.australia.(2018).eng.1cd
# 2484   9268343      castle.s07.e16.the.wrong.stuff.(2015).eng.1cd
# 18175  9274584            scrubs.s06.e21.my.rabbit.(2007).eng.1cd
# 6173   9325723  gold.rush.white.water.s06.e02.into.the.unknown...
# 4038   9510375  the.warp.effect.s01.e07.im.not.ashamed.(2023)....
#
#                                             file_content  \
# 16568  [Script Info]\r\nTitle: English (US)\r\nOrigin...
# 17274  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nSuppo...
# 21694  ï»¿[Script Info]\r\n; Script generated by Aegi...
# 9570   1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 3075   ï»¿1\r\n00:00:05,964 --> 00:00:07,966\r\n[dram...
# 18162  WEBVTT\n\nï»¿1\n00:00:00.144 --> 00:00:02.459\...
# 11318  ï»¿1\r\n00:00:02,135 --> 00:00:06,664\r\nMAN [...
# 21580  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 21493  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
# 21434  1\r\n00:00:05,520 --> 00:00:07,480\r\nWe know ...
# 16444  ï»¿1\r\n00:00:06,390 --> 00:00:09,191\r\nSELIN...
# 236    ï»¿1\r\n00:00:09,360 --> 00:00:11,520\r\nFar a...
# 13941  ï»¿[Script Info]\r\n; Script generated by Aegi...
# 12890  ï»¿1\r\n00:03:07,875 --> 00:03:10,041\r\nOf co...
# 20518  ï»¿1\r\n00:00:07,882 --> 00:00:09,175\r\nDomen...
# 18361  1\r\n00:00:06,000 --> 00:00:12,074\r\nSupport ...
# 6019   ï»¿1\r\n00:00:02,627 --> 00:00:04,504\r\n**\r\...
# 19337  1\n00:00:00,300 --> 00:00:03,300\nSubtitles by...
# 10165  [Script Info]\r\nTitle: English (US)\r\nOrigin...
# 20152  ï»¿1\r\n00:00:10,677 --> 00:00:14,637\r\nCapti...
# 14313  ï»¿1\r\n00:00:06,924 --> 00:00:08,593\r\n- (BI...
# 15872  ï»¿1\r\n00:00:04,000 --> 00:00:09,760\r\nPrevi...
# 24414  ï»¿1\r\n00:00:02,052 --> 00:00:04,720\r\n<i>â...
# 1087   ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nUse t...
# 8547   1\r\n00:00:06,000 --> 00:00:12,074\r\nSupport ...
# 20578  ï»¿1\r\n00:00:07,107 --> 00:00:08,743\r\n- <i>...
# 1457   ï»¿1\r\n00:00:04,463 --> 00:00:07,675\r\nCHAE ...
# 19904  ï»¿1\r\n00:00:08,809 --> 00:00:11,244\r\nFirst...
# 13857  1\r\n00:00:06,000 --> 00:00:12,074\r\nSupport ...
# 23633  ï»¿1\r\n00:00:07,608 --> 00:00:09,236\r\nNarra...
# 4084   1\r\n00:00:06,000 --> 00:00:12,074\r\napi.Open...
# 18151  ï»¿1\r\n00:00:03,204 --> 00:00:06,099\r\nIt's ...
# 9591   ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# 14515  ï»¿1\r\n00:00:01,320 --> 00:00:02,560\r\nBIKER...
# 3388   ï»¿1\r\n00:00:02,152 --> 00:00:03,752\r\n<i>My...
# 12330  ï»¿1\r\n00:00:16,017 --> 00:00:17,861\r\n- Hey...
# 14457  ï»¿1\r\n00:00:13,040 --> 00:00:15,150\r\nIt wa...
# 10765  ï»¿1\r\n00:00:00,640 --> 00:00:02,176\r\nPrevi...
# 16933  ï»¿1\r\n00:00:01,919 --> 00:00:03,719\r\n<i>Ma...
# 8829   ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 5440   ï»¿1\r\n00:00:02,728 --> 00:00:04,378\r\n("Wei...
# 20605  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nUse t...
# 19127  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 16971  ï»¿1\r\n00:00:03,232 --> 00:00:06,985\r\nPICAR...
# 14621  ï»¿1\r\n00:00:01,335 --> 00:00:02,801\r\n<i>PR...
# 160    ï»¿1\r\n00:00:04,920 --> 00:00:08,520\r\nPrevi...
# 2484   ï»¿1\r\n00:00:07,491 --> 00:00:10,992\r\nYou k...
# 18175  ï»¿1\r\n00:00:04,771 --> 00:00:07,383\r\n<i>J....
# 6173   1\r\n00:00:02,206 --> 00:00:05,172\r\n[Tense m...
# 4038   ï»¿1\r\n00:00:00,109 --> 00:00:01,744\r\nI kno...
#
#                                         clean_text_lemma  text_length_lemma
# 16568  script info title english u original script to...               3010
# 17274  support u and become vip member to remove all ...               9497
# 21694  script info script generated by aegisub http w...               8422
# 9570   advertise your product or brand here contact w...               4373
# 3075   dramatic music playing an chelsea sigh well he...               7850
# 18162  webvtt air whoosh softly upbeat groove music a...              21121
# 11318  man on tv carroll wa convicted in for the murd...               3313
# 21580  advertise your product or brand here contact w...               5743
# 21493  watch any video online with open subtitle free...               6195
# 21434  we know who is the partner of the contractor i...               4043
# 16444  selina congresswoman nickerson i just want you...               5518
# 236    far away cut off by vast ocean lie earth s tro...               3365
# 13941  script info script generated by aegisub http w...              13047
# 12890  of course it make perfect sense he s completel...                197
# 20518  domenica today is the day gina there s no plac...              13823
# 18361  support u and become vip member to remove all ...               5044
# 6019   daly tonight the final night of battle gwen wo...               7187
# 19337  subtitle by dramafever goblin the lonely and g...               6390
# 10165  script info title english u original script tv...               3465
# 20152  captioning sponsored by fox broadcasting compa...               3061
# 14313  bird chirping engine revving teenager grunting...               5519
# 15872  previously on love island snog the three fitte...               7984
# 24414  it seems today that all you see is violence in...               3127
# 1087   use the free code joinnow at www playships eu ...               3171
# 8547   support u and become vip member to remove all ...               2467
# 20578  hey phil yeah we re about to go up going up in...               6252
# 1457   chae jong hyeop seo eun su park sung woong sup...               3942
# 19904  first box go in my car the other in the truck ...               2779
# 13857  support u and become vip member to remove all ...               2498
# 23633  narrator thousand of shark silkies white tip h...               5234
# 4084   api opensubtitles org is deprecated please imp...               4454
# 18151  it s on election night and a you can see the t...               5268
# 9591   advertise your product or brand here contact w...               2633
# 14515  biker gang becomes more violent in doing crimi...               6856
# 3388   my name is fox mulder since my childhood i hav...               4514
# 12330  hey stay back guy stay back whoa hey hey sweet...               4918
# 14457  it wa a small knife no bigger than a pocket kn...               2666
# 10765  previously on prisoner zero zero want me to ch...               2267
# 16933  mac you gotta see this movie dude really i tho...               4199
# 8829   script info title default file scripttype v wr...               9424
# 5440   weird al yankovic sings playing the simpson th...               2724
# 20605  use the free code joinnow at www playships eu ...               6780
# 19127  watch any video online with open subtitle free...              13470
# 16971  picard captain s log stardate the enterprise h...               4894
# 14621  previously on roswell you know how we agreed n...               4618
# 160    previously on love island australia twin bomb ...               8996
# 2484   you know after six month mar is starting to re...               6962
# 18175  j d the reason time had slowed down wa because...               3622
# 6173   tense music playing dustin an we have all of o...               7019
# 4038   i know what happened at jedi s now jean told m...               4293

# %%
df_20 = df_new.sample(frac=0.2)

# %%
# df_20.to_csv('data/search_eng_data_20_percent.csv', index=False, escapechar="\\")

# %%
df_20
# Out:
#            num                                               name  \
# 14613  9426103                   les.bonnes.femmes.(1960).eng.1cd
# 19429  9432248    dam.s01.e05.the.past.is.not.dead.(2021).eng.1cd
# 17979  9266391                    little.manhattan.(2005).eng.1cd
# 1534   9250897  jamtara.sabka.number.ayega.s02.e01.episode.2.1...
# 14433  9517056  my.sisters.serial.killer.boyfriend.(2023).eng.1cd
# ...        ...                                                ...
# 8498   9216854               sover.dolly.pa.ryggen.(2012).eng.1cd
# 22555  9237797  young.sheldon.s05.e03.potential.energy.and.hoo...
# 18170  9469768  australian.survivor.s07.e05.episode.7.5.(2022)...
# 5687   9488726  being.human.s04.e04.the.panic.womb.(2014).eng.1cd
# 11060  9266296     the.midnight.club.s01.e06.witch.(2022).eng.1cd
#
#                                             file_content  \
# 14613  1\r\n00:00:06,000 --> 00:00:12,074\r\nSupport ...
# 19429  1\r\n00:00:00,480 --> 00:00:03,480\r\n(water b...
# 17979  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 1534   ï»¿1\r\n00:00:11,400 --> 00:00:13,520\r\nThere...
# 14433  1\r\n00:00:06,000 --> 00:00:12,074\r\nSupport ...
# ...                                                  ...
# 8498   ï»¿1\r\n00:00:09,166 --> 00:00:12,166\r\nAnd y...
# 22555  ï»¿1\r\n00:00:02,295 --> 00:00:03,689\r\n[adul...
# 18170  ï»¿1\r\n00:00:01,000 --> 00:00:07,600\r\nJONAT...
# 5687   ï»¿1\r\n00:00:02,836 --> 00:00:04,605\r\n- Pre...
# 11060  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
#
#                                         clean_text_lemma  text_length_lemma
# 14613  support u and become vip member to remove all ...               5266
# 19429  water boiling advertise your product or brand ...               2393
# 17979  advertise your product or brand here contact w...              10585
# 1534   there wa a time when dacoit would kill people ...               4051
# 14433  support u and become vip member to remove all ...               8336
# ...                                                  ...                ...
# 8498   and you re sure about this yes you re you ve g...               7767
# 22555  adult sheldon previously on young sheldon did ...               3153
# 18170  jonathan lapaglia previously on australian sur...               7316
# 5687   previously travelling through time l il smokie...               6082
# 11060  advertise your product or brand here contact w...               5403
#
# [4950 rows x 5 columns]
